# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
import numpy as np
x=np.array([[2],[4],[6],[8],[10],[12],[14]])
y=np.array(['20000','40000','55000','85000','100000','120000','140000'])
lr.fit(x,y)
# Out:
# [[ 2]
#  [ 4]
#  [ 6]
#  [ 8]
#  [10]
#  [12]
#  [14]]
# ['20000,40000' '55000' '85000' '100000' '120000' '140000']

# %%
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 2.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/8.9 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.9 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.9 MB 2.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/8.9 MB 2.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/8.9 MB 2.2 MB/s eta 0:00:03
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
import numpy as np
x=np.array([[2],[4],[6],[8],[10],[12],[14]])
y=np.array(['20000','40000','55000','85000','100000','120000','140000'])
lr.fit(x,y)
loef=lr.coef_[0]
loef
# Out:
# np.float64(10089.285714285714)

# %%
intrcept=lr.intercept_
intrcept
# Out:
# np.float64(-714.2857142857101)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
x=([[2],[4],[6],[8],[10],[12],[14]])
y=([20000,40000,55000,85000,100000,120000,140000])
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
coef = lr.coef_[0]
coef
# Out:
# np.float64(10089.285714285714)

# %%
intrcept=lr.intercept_
intrcept
# Out:
# np.float64(-714.2857142857101)

# %%
exp=int(input('enter the numer'))
pred_sal=coef*exp+intrcept
print(pred_sal)
# Out:
# 4586033660.714286

# %%
print('sdff')
# Out:
# sdff
